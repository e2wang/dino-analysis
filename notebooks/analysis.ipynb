# %% [markdown]
# # Data Analysis of Dinosaur Features

# %% [markdown]
# By Elsie Wang
#
# Purpose: Import and clean data, perform data analysis
#
# Date: 04/06/24

# %%
# Import statements
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import regex as re
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import datasets
jurassic = pd.read_csv('../data/jurassic_park.csv')
jurassic.head()
# Out:
#                name         diet                                      period  \
# 0          aardonyx  herbivorous    Early Jurassic 199-189 million years ago
# 1       abelisaurus  carnivorous     Late Cretaceous 74-70 million years ago
# 2     achelousaurus  herbivorous     Late Cretaceous 83-70 million years ago
# 3      achillobator  carnivorous     Late Cretaceous 99-84 million years ago
# 4  acrocanthosaurus  carnivorous  Early Cretaceous 115-105 million years ago
#
#        lived_in            type length  \
# 0  South Africa        sauropod   8.0m
# 1     Argentina  large theropod   9.0m
# 2           USA     ceratopsian   6.0m
# 3      Mongolia  large theropod   5.0m
# 4           USA  large theropod  12.0m
#
#                                             taxonomy  \
# 0  Dinosauria Saurischia Sauropodomorpha Prosauro...
# 1  Dinosauria Saurischia Theropoda Neotheropoda C...
# 2  Dinosauria Ornithischia Genasauria Cerapoda Ma...
# 3  Dinosauria Saurischia Theropoda Neotheropoda T...
# 4  Dinosauria Saurischia Theropoda Neotheropoda T...
#
#                                             named_by      species  \
# 0  Yates Bonnan Neveling Chinsamy and Blackbeard ...     celestae
# 1                         Bonaparte and Novas (1985)  comahuensis
# 2                                    Sampson  (1995)      horneri
# 3                      Perle Norell and Clark (1999)    giganteus
# 4                        Stovall and Langston (1950)    atokensis
#
#                                                 link
# 0  https://www.nhm.ac.uk/discover/dino-directory/...
# 1  https://www.nhm.ac.uk/discover/dino-directory/...
# 2  https://www.nhm.ac.uk/discover/dino-directory/...
# 3  https://www.nhm.ac.uk/discover/dino-directory/...
# 4  https://www.nhm.ac.uk/discover/dino-directory/...

# %% [markdown]
# ## Data Cleaning

# %%
def extract_duration(row):
    """Takes period text and returns the time span"""
    pattern = r'(\d+)-(\d+)'
    match = re.search(pattern, row)
    if match:
        start_year = int(match.group(1))
        end_year = int(match.group(2))
        return np.abs(end_year - start_year)
    else:
        return

# %%
# Create column extract time period
pattern = r'^\w+\s+(\w+)'
jurassic['time_period'] = jurassic['period'].str.extract(pattern)

# Create column extract time span
jurassic['time_span'] = jurassic['period'].apply(extract_duration)

# Drop NaN values
jurassic_cleaned = jurassic.dropna()
jurassic_cleaned
# Out:
#                  name         diet  \
# 0            aardonyx  herbivorous
# 1         abelisaurus  carnivorous
# 2       achelousaurus  herbivorous
# 3        achillobator  carnivorous
# 4    acrocanthosaurus  carnivorous
# ..                ...          ...
# 301      yimenosaurus  herbivorous
# 303           yinlong  herbivorous
# 304     yuanmousaurus  herbivorous
# 305     yunnanosaurus   omnivorous
# 307     zephyrosaurus  herbivorous
#
#                                          period      lived_in            type  \
# 0      Early Jurassic 199-189 million years ago  South Africa        sauropod
# 1       Late Cretaceous 74-70 million years ago     Argentina  large theropod
# 2       Late Cretaceous 83-70 million years ago           USA     ceratopsian
# 3       Late Cretaceous 99-84 million years ago      Mongolia  large theropod
# 4    Early Cretaceous 115-105 million years ago           USA  large theropod
# ..                                          ...           ...             ...
# 301    Early Jurassic 195-190 million years ago         China        sauropod
# 303      Mid Jurassic 159-154 million years ago         China     ceratopsian
# 304      Mid Jurassic 180-159 million years ago         China        sauropod
# 305    Early Jurassic 205-190 million years ago         China        sauropod
# 307  Early Cretaceous 120-110 million years ago           USA    euornithopod
#
#     length                                           taxonomy  \
# 0     8.0m  Dinosauria Saurischia Sauropodomorpha Prosauro...
# 1     9.0m  Dinosauria Saurischia Theropoda Neotheropoda C...
# 2     6.0m  Dinosauria Ornithischia Genasauria Cerapoda Ma...
# 3     5.0m  Dinosauria Saurischia Theropoda Neotheropoda T...
# 4    12.0m  Dinosauria Saurischia Theropoda Neotheropoda T...
# ..     ...                                                ...
# 301   9.0m  Dinosauria Saurischia Sauropodomorpha Prosauro...
# 303   1.2m  Dinosauria Ornithischia Genasauria Cerapoda Ma...
# 304  17.0m  Dinosauria Saurischia Sauropodomorpha Sauropod...
# 305   7.0m  Dinosauria Saurischia Sauropodomorpha Prosauro...
# 307   1.8m  Dinosauria Ornithischia Genasauria Cerapoda Or...
#
#                                               named_by       species  \
# 0    Yates Bonnan Neveling Chinsamy and Blackbeard ...      celestae
# 1                           Bonaparte and Novas (1985)   comahuensis
# 2                                      Sampson  (1995)       horneri
# 3                        Perle Norell and Clark (1999)     giganteus
# 4                          Stovall and Langston (1950)     atokensis
# ..                                                 ...           ...
# 301                           Bai Yang and Wang (1990)        youngi
# 303                     Xu Forster Clark and Mo (2006)        downsi
# 304                Lü Li Ji Wang Zhang and Dong (2006)  jiangyiensis
# 305                                       Young (1942)        huangi
# 307                                        Sues (1980)       schaffi
#
#                                                   link time_period  time_span
# 0    https://www.nhm.ac.uk/discover/dino-directory/...    Jurassic       10.0
# 1    https://www.nhm.ac.uk/discover/dino-directory/...  Cretaceous        4.0
# 2    https://www.nhm.ac.uk/discover/dino-directory/...  Cretaceous       13.0
# 3    https://www.nhm.ac.uk/discover/dino-directory/...  Cretaceous       15.0
# 4    https://www.nhm.ac.uk/discover/dino-directory/...  Cretaceous       10.0
# ..                                                 ...         ...        ...
# 301  https://www.nhm.ac.uk/discover/dino-directory/...    Jurassic        5.0
# 303  https://www.nhm.ac.uk/discover/dino-directory/...    Jurassic        5.0
# 304  https://www.nhm.ac.uk/discover/dino-directory/...    Jurassic       21.0
# 305  https://www.nhm.ac.uk/discover/dino-directory/...    Jurassic       15.0
# 307  https://www.nhm.ac.uk/discover/dino-directory/...  Cretaceous       10.0
#
# [258 rows x 12 columns]

# %%
# Create column to group countries by continent
countries_continents = { 'Argentina': 'South America', 
                        'Australia': 'Australia', 
                        'Brazil': 'South America', 
                        'Canada': 'North America', 
                        'China': 'Asia', 
                        'Egypt': 'Africa', 
                        'France': 'Europe', 
                        'Germany': 'Europe', 
                        'India': 'Asia', 
                        'Japan': 'Asia', 
                        'Kazakhstan': 'Asia', 
                        'Lesotho': 'Africa', 
                        'Madagascar': 'Africa', 
                        'Malawi': 'Africa', 
                        'Mongolia': 'Asia', 
                        'Morocco': 'Africa', 
                        'Niger': 'Africa', 
                        'North Africa': 'Africa', 
                        'Romania': 'Europe', 
                        'Russia': 'Asia', 
                        'South Africa': 'Africa', 
                        'Spain': 'Europe', 
                        'Tanzania': 'Africa', 
                        'Tunisia': 'Africa', 
                        'USA': 'North America', 
                        'United Kingdom': 'Europe', 
                        'Uruguay': 'South America', 
                        'Uzbekistan': 'Asia', 
                        'Zimbabwe': 'Africa' } 

jurassic_cleaned['continent'] = jurassic_cleaned['lived_in'].replace(countries_continents)
jurassic_cleaned.head()
# Out:
#                name         diet                                      period  \
# 0          aardonyx  herbivorous    Early Jurassic 199-189 million years ago
# 1       abelisaurus  carnivorous     Late Cretaceous 74-70 million years ago
# 2     achelousaurus  herbivorous     Late Cretaceous 83-70 million years ago
# 3      achillobator  carnivorous     Late Cretaceous 99-84 million years ago
# 4  acrocanthosaurus  carnivorous  Early Cretaceous 115-105 million years ago
#
#        lived_in            type length  \
# 0  South Africa        sauropod   8.0m
# 1     Argentina  large theropod   9.0m
# 2           USA     ceratopsian   6.0m
# 3      Mongolia  large theropod   5.0m
# 4           USA  large theropod  12.0m
#
#                                             taxonomy  \
# 0  Dinosauria Saurischia Sauropodomorpha Prosauro...
# 1  Dinosauria Saurischia Theropoda Neotheropoda C...
# 2  Dinosauria Ornithischia Genasauria Cerapoda Ma...
# 3  Dinosauria Saurischia Theropoda Neotheropoda T...
# 4  Dinosauria Saurischia Theropoda Neotheropoda T...
#
#                                             named_by      species  \
# 0  Yates Bonnan Neveling Chinsamy and Blackbeard ...     celestae
# 1                         Bonaparte and Novas (1985)  comahuensis
# 2                                    Sampson  (1995)      horneri
# 3                      Perle Norell and Clark (1999)    giganteus
# 4                        Stovall and Langston (1950)    atokensis
#
#                                                 link time_period  time_span  \
# 0  https://www.nhm.ac.uk/discover/dino-directory/...    Jurassic       10.0
# 1  https://www.nhm.ac.uk/discover/dino-directory/...  Cretaceous        4.0
# 2  https://www.nhm.ac.uk/discover/dino-directory/...  Cretaceous       13.0
# 3  https://www.nhm.ac.uk/discover/dino-directory/...  Cretaceous       15.0
# 4  https://www.nhm.ac.uk/discover/dino-directory/...  Cretaceous       10.0
#
#        continent
# 0         Africa
# 1  South America
# 2  North America
# 3           Asia
# 4  North America

# %% [markdown]
# ## Exploratory Data Analysis

# %%
def generate_plots(period, continent):
    """Return list of plots comparing timspan and feature variables"""

    # Filter by time period and continent
    df = jurassic_cleaned[(jurassic_cleaned['time_period'] == period) & (jurassic_cleaned['continent'] == continent)]

    # Line graph
    

    
    
    return

# %%
generate_plots('Cretaceous', 'Africa')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 generate_plots('Cretaceous', 'Africa')
#
# Cell In[115], line 7, in generate_plots(period, continent)
#       4 # Filter by time period and continent
#       5 df = jurassic_cleaned[(jurassic_cleaned['time_period'] == period) & (jurassic_cleaned['continent'] == continent)]
# ----> 7 hello = plt.bar(timespan, diet, width=0.4, color='r', label='Diet B')
#      11 return hello
#
# NameError: name 'timespan' is not defined
